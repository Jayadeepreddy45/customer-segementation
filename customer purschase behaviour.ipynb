# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# %%
df = pd.read_excel('/content/customer_purchase_behaviour.xlsx')
df.head()
# Out:
#    Age  Purchase_Amount   Review_Rating Items_Purchased            Category  \
# 0   28              2500            4.5           Kurta            Clothing
# 1   34             15000            4.7      Smartphone         Electronics
# 2   22               600            3.8        Notebook          Stationery
# 3   40              9000            4.9   Mixer Grinder  Kitchen Appliances
# 4   19              1200            4.2        Sneakers            Footwear
#
#     Location  Colour   Season Payment_Method  Purchase_Frequency
# 0      Delhi    Blue   Summer            UPI                   3
# 1     Mumbai   Black  Monsoon    Credit Card                   1
# 2  Bengaluru     Red   Winter           Cash                  10
# 3    Chennai  Silver   Summer     Debit Card                   1
# 4    Kolkata   White   Spring            UPI                   2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 127 non-null    int64
#  1   Purchase_Amount     127 non-null    int64
#  2   Review_Rating       127 non-null    float64
#  3   Items_Purchased     127 non-null    object
#  4   Category            127 non-null    object
#  5   Location            127 non-null    object
#  6   Colour              127 non-null    object
#  7   Season              127 non-null    object
#  8   Payment_Method      127 non-null    object
#  9   Purchase_Frequency  127 non-null    int64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 10.0+ KB

# %%
df.Category.value_counts()
# Out:
# Category
# Electronics           35
# Accessories           25
# Home Appliances       24
# Clothing              17
# Kitchen Appliances    17
# Footwear               8
# Stationery             1
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Category'] = le.fit_transform(df['Category'])
df.head()
# Out:
#    Age  Purchase_Amount   Review_Rating Items_Purchased  Category   Location  \
# 0   28              2500            4.5           Kurta         1      Delhi
# 1   34             15000            4.7      Smartphone         2     Mumbai
# 2   22               600            3.8        Notebook         6  Bengaluru
# 3   40              9000            4.9   Mixer Grinder         5    Chennai
# 4   19              1200            4.2        Sneakers         3    Kolkata
#
#    Colour   Season Payment_Method  Purchase_Frequency
# 0    Blue   Summer            UPI                   3
# 1   Black  Monsoon    Credit Card                   1
# 2     Red   Winter           Cash                  10
# 3  Silver   Summer     Debit Card                   1
# 4   White   Spring            UPI                   2

# %%
df.Payment_Method.value_counts()
# Out:
# Payment_Method
# UPI            38
# Credit Card    38
# Debit Card     33
# Cash           17
# Net Banking     1
# Name: count, dtype: int64

# %%
le = LabelEncoder()
df['Payment_Method'] = le.fit_transform(df['Payment_Method'])
df.head()
# Out:
#    Age  Purchase_Amount   Review_Rating Items_Purchased  Category   Location  \
# 0   28              2500            4.5           Kurta         1      Delhi
# 1   34             15000            4.7      Smartphone         2     Mumbai
# 2   22               600            3.8        Notebook         6  Bengaluru
# 3   40              9000            4.9   Mixer Grinder         5    Chennai
# 4   19              1200            4.2        Sneakers         3    Kolkata
#
#    Colour   Season  Payment_Method  Purchase_Frequency
# 0    Blue   Summer               4                   3
# 1   Black  Monsoon               1                   1
# 2     Red   Winter               0                  10
# 3  Silver   Summer               2                   1
# 4   White   Spring               4                   2

# %%
df.Season.value_counts()
# Out:
# Season
# Winter     39
# Summer     38
# Monsoon    34
# Spring     16
# Name: count, dtype: int64

# %%
le = LabelEncoder()
df['Season'] = le.fit_transform(df['Season'])
df.head()
# Out:
#    Age  Purchase_Amount   Review_Rating Items_Purchased  Category   Location  \
# 0   28              2500            4.5           Kurta         1      Delhi
# 1   34             15000            4.7      Smartphone         2     Mumbai
# 2   22               600            3.8        Notebook         6  Bengaluru
# 3   40              9000            4.9   Mixer Grinder         5    Chennai
# 4   19              1200            4.2        Sneakers         3    Kolkata
#
#    Colour  Season  Payment_Method  Purchase_Frequency
# 0    Blue       2               4                   3
# 1   Black       0               1                   1
# 2     Red       3               0                  10
# 3  Silver       2               2                   1
# 4   White       1               4                   2

# %%
df.Colour.value_counts()
# Out:
# Colour
# Black     39
# White     28
# Silver    14
# Blue      13
# Brown     11
# Red        8
# Grey       7
# Pink       4
# Green      3
# Name: count, dtype: int64

# %%
le = LabelEncoder()
df['Colour'] = le.fit_transform(df['Colour'])
df.head()
# Out:
#    Age  Purchase_Amount   Review_Rating Items_Purchased  Category   Location  \
# 0   28              2500            4.5           Kurta         1      Delhi
# 1   34             15000            4.7      Smartphone         2     Mumbai
# 2   22               600            3.8        Notebook         6  Bengaluru
# 3   40              9000            4.9   Mixer Grinder         5    Chennai
# 4   19              1200            4.2        Sneakers         3    Kolkata
#
#    Colour  Season  Payment_Method  Purchase_Frequency
# 0       1       2               4                   3
# 1       0       0               1                   1
# 2       6       3               0                  10
# 3       7       2               2                   1
# 4       8       1               4                   2

# %%
df.Location.value_counts()
# Out:
# Location
# Jaipur                6
# Delhi                 4
# Bengaluru             4
# Chennai               4
# Kolkata               4
# Mumbai                4
# Jodhpur               3
# Shillong              3
# Gwalior               3
# Coimbatore            3
# Amritsar              3
# Surat                 3
# Madurai               3
# Varanasi              3
# Ranchi                3
# Bhubaneswar           3
# Jabalpur              3
# Shimla                3
# Nashik                3
# Srinagar              3
# Nagpur                3
# Panaji                3
# Thiruvananthapuram    3
# Lucknow               3
# Patna                 3
# Raipur                3
# Bhopal                3
# Chandigarh            3
# Kochi                 3
# Indore                3
# Mysuru                3
# Visakhapatnam         3
# Ahmedabad             3
# Hyderabad             3
# Guwahati              3
# Pune                  3
# Meerut                1
# Jammu                 1
# ...

# %%
le = LabelEncoder()
df['Location'] = le.fit_transform(df['Location'])
df.head()
# Out:
#    Age  Purchase_Amount   Review_Rating Items_Purchased  Category  Location  \
# 0   28              2500            4.5           Kurta         1        10
# 1   34             15000            4.7      Smartphone         2        27
# 2   22               600            3.8        Notebook         6         3
# 3   40              9000            4.9   Mixer Grinder         5         7
# 4   19              1200            4.2        Sneakers         3        22
#
#    Colour  Season  Payment_Method  Purchase_Frequency
# 0       1       2               4                   3
# 1       0       0               1                   1
# 2       6       3               0                  10
# 3       7       2               2                   1
# 4       8       1               4                   2

# %%
df.Items_Purchased.value_counts()
# Out:
# Items_Purchased
# Sunglasses             6
# Refrigerator           4
# Vacuum Cleaner         4
# Wallet                 4
# Air Conditioner        4
# Perfume                4
# Washing Machine        4
# Casual Shoes           4
# Mixer                  3
# Water Purifier         3
# Formal Shirt           3
# Sports Shoes           3
# Backpack               3
# Belt                   3
# Smartwatch             3
# Jacket                 3
# Headphones             3
# T-shirt                3
# Air Purifier           3
# Home Theater System    3
# Pen Drive              3
# Dishwasher             3
# Microwave Oven         3
# Polo T-shirt           3
# Gaming Console         3
# Lipstick               3
# LED TV                 3
# Electric Kettle        3
# Fitness Tracker        3
# Laptop                 3
# Wireless Charger       2
# Shirt                  2
# Toaster                2
# Coffee Maker           2
# DSLR Camera            2
# Smart TV               2
# ...

# %%
le = LabelEncoder()
df['Items_Purchased'] = le.fit_transform(df['Items_Purchased'])
df.head()
# Out:
#    Age  Purchase_Amount   Review_Rating  Items_Purchased  Category  Location  \
# 0   28              2500            4.5               21         1        10
# 1   34             15000            4.7               37         2        27
# 2   22               600            3.8               29         6         3
# 3   40              9000            4.9               28         5         7
# 4   19              1200            4.2               39         3        22
#
#    Colour  Season  Payment_Method  Purchase_Frequency
# 0       1       2               4                   3
# 1       0       0               1                   1
# 2       6       3               0                  10
# 3       7       2               2                   1
# 4       8       1               4                   2

# %%
df.corr()
# Out:
#                          Age  Purchase_Amount   Review_Rating  \
# Age                 1.000000          0.694592       0.756407
# Purchase_Amount     0.694592          1.000000       0.808041
# Review_Rating       0.756407          0.808041       1.000000
# Items_Purchased    -0.097395         -0.085127      -0.100185
# Category            0.486906          0.353100       0.595538
# Location            0.039130          0.015567      -0.058897
# Colour              0.231905          0.130023       0.274084
# Season             -0.150417         -0.218606      -0.238858
# Payment_Method     -0.423729         -0.384052      -0.366259
# Purchase_Frequency -0.469463         -0.522561      -0.684637
#
#                     Items_Purchased  Category  Location    Colour    Season  \
# Age                       -0.097395  0.486906  0.039130  0.231905 -0.150417
# Purchase_Amount           -0.085127  0.353100  0.015567  0.130023 -0.218606
# ...

# %%
 df.plot(kind = 'scatter', x = 'Age', y = 'Review_Rating')
 plt.show()

# %%
 inertia = []
 K = range(1, 10)
 for k in K:
     kmeans = KMeans(n_clusters=k, random_state=42)
     kmeans.fit(df)
     inertia.append(kmeans.inertia_)

 plt.plot(K, inertia, 'bx-')
 plt.xlabel('Number of Clusters')
 plt.ylabel('Inertia')
 plt.title('Elbow Method For Optimal k')
 plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
 kmeans = KMeans(n_clusters=3, random_state=42)
 kmeans.fit(df)
 df['Cluster'] = kmeans.labels_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
 import matplotlib.pyplot as plt

 plt.figure(figsize=(10, 6))
 plt.scatter(df['Age'], df['Review_Rating'], c=df['Cluster'], cmap='viridis')
 plt.xlabel('Age')
 plt.ylabel('Purchase Amount')
 plt.title('Clusters based on Age and review rating')
 plt.colorbar(label='Cluster')
 plt.show()
